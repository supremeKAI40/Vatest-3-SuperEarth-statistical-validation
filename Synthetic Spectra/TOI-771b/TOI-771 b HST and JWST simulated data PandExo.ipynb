# %%
import pandas as pd
import numpy as np
import sys
import seaborn as sns
import pylab as plt
#HCT TOI-771b
pickleFile = open("ETC-calculation1963a96d-dca5-4186-9489-feb836f42d17h.p","rb")

obj = pd.read_pickle(pickleFile)
print (obj)
# Out:
# {'wfc3_TExoNS': {'spec_error': 4.7200787786822676e-05, 'light_curve_rms': 0.0002670079769712759, 'nframes_per_orb': 17.0, 'info': {'Number of HST orbits': 4.0, 'Use first orbit': False, 'WFC3 parameters: NSAMP': 7, 'WFC3 parameters: SAMP_SEQ': 'SPARS25', 'Scan Direction': 'Round Trip', 'Recommended scan rate (arcsec/s)': 0.03812002110851161, 'Scan height (pixels)': 43.59569435547705, 'Maximum pixel fluence (electrons)': 30000.000000000004, 'exposure time': 138.3808, 'Estimated duty cycle (outside of Earth occultation)': 73.80309333333332, 'Transit depth uncertainty(ppm)': 47.20078778682267, 'Number of channels': 10, 'Number of Transits': 3, 'Start observations between orbital phases': '0.9325266556943113-0.9384977481107439'}}, 'calc_start_window': {'obsphase1': array([0.93252666, 0.93342232, 0.93431798, 0.93521365, 0.93610931,
#        0.93700498, 0.93790064, 0.9387963 , 0.93969197, 0.94058763,
#        0.94148329, 0.94237896, 0.94327462, 0.94417029, 0.94506595,
# ...
