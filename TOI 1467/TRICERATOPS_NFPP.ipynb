# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import time
from lightkurve import TessLightCurve
import matplotlib.pyplot as plt
# %matplotlib inline

import triceratops.triceratops as tr

# %% [markdown]
# # User Inputs
#
# * **ID** = TIC ID of selected target
# * **sectors** = Observational sector of TESS
#
#
# * **period** = Orbital Period
# * **tdepth** = Transit Depth
#
#
# * **lc** = Light curve file
# * **contrastcurve_file** = Contrast curve file
#
#
# * **band** = Band of filter through which CC file was created. (TESS, Vis, J, H, K)
# From table below we can identify which band to choose.
#
# |   Wavelength   | Central Wavelength | Filter |
# |:--------------:|:------------------:|:------:|
# |  600 - 1000 nm | 786.5 nm           |  TESS  |
# |   400 - 800 nm | 550 nm             |   Vis  |
# | 1000 - 1500 nm | 1250 nm            |   J    |
# | 1400 - 2000 nm | 1650 nm            |   H    |
# | 1800 - 2600 nm | 2200 nm            |   K    |
#
# * We usually encounter with following wavelengths,
#  - **562 nm** : Vis filter
#  - **832 nm** : TESS filter
#  - **Br-Gamma** (2172 - 2202 nm) : K filter
#  - **Jcont** (1190 - 1230 nm) : J filter

# %%
ID = 240968774
sectors = np.array([17,18])

period = 5.9711424562
tdepth = 0.001231323616846885

lc_file = "TOI_1467_S17_18_58.csv"
contrastcurve_file = "TOI_1467_562nm.csv"

band = 'Vis'

# %% [markdown]
# # Downloading & Visualizing Data

# %%
target = tr.target(ID=ID, sectors=sectors)

# %%
ap17 = np.array([[1686,1463],[1687,1463],[1685,1464],[1686,1464],
                 [1687,1464],[1688,1464],[1685,1465],[1686,1465],
                 [1687,1465],[1688,1465],[1685,1466],[1686,1466],
                 [1687,1466]])

ap18 = np.array([[332,1471],[333,1471],[334,1471],[331,1472],[332,1472],
                 [333,1472],[334,1472],[331,1473],[332,1473],[333,1473],
                 [334,1473],[331,1474],[332,1474],[333,1474],[334,1474],
                 [332,1475],[333,1475]])

#ap58 = np.array([[759,1188],[760,1188],[761,1188],[762,1188],[759,1189],
#                 [760,1189],[761,1189],[762,1189],[759,1190],[760,1190],
#                 [761,1190],[762,1190],[760,1191],[761,1191],[762,1191]])

apertures = np.array([ap17, ap18])

for i,(sector,aperture) in enumerate(zip(sectors,apertures)):
    print("Sector", sector)
    target.plot_field(sector=sector, ap_pixels=aperture)

target.stars
# Out:
# C:\Users\Aniket Prasad\AppData\Local\Temp\ipykernel_9352\1675860004.py:15: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   apertures = np.array([ap17, ap18])
# Sector 17
# Sector 18
#             ID     Tmag    Jmag    Hmag    Kmag         ra        dec  \
# 0    240968774  10.5977   9.380   8.791   8.568  19.113929  49.233780
# 1    602264101  20.1211     NaN     NaN     NaN  19.116086  49.234115
# 2    240968773  16.8007  15.770  15.558  14.920  19.107401  49.232925
# 3    602272535  18.6427     NaN     NaN     NaN  19.125483  49.237533
# 4    602272536  18.4817     NaN     NaN     NaN  19.123414  49.239829
# ..         ...      ...     ...     ...     ...        ...        ...
# 266  240968730  16.6550  15.588  14.925  14.994  19.059456  49.191013
# 267  602264145  20.6790     NaN     NaN     NaN  19.032843  49.216625
# 268  602264143  19.3522     NaN     NaN     NaN  19.037341  49.209165
# 269  602272247  19.7174     NaN     NaN     NaN  19.199501  49.233375
# 270  240968835  11.3857  10.467   9.986   9.897  19.097599  49.288640
#
#          mass       rad     Teff        plx  sep (arcsec)  PA (E of N)
# 0    0.488826  0.490737  3834.00  26.679300         0.000        0.000
# 1         NaN       NaN      NaN        NaN         5.210       76.635
# 2    0.880000  0.711585  5176.00   0.543496        15.652      258.660
# 3         NaN       NaN  5531.00  -0.309165        30.334       63.546
# 4         NaN       NaN  3444.00   1.693440        31.165       45.667
# ..        ...       ...      ...        ...           ...          ...
# 266  0.770000  0.933857  4758.00   0.526237       200.287      219.783
# 267       NaN       NaN      NaN        NaN       200.398      252.081
# 268       NaN       NaN  4772.00  -0.672445       200.703      243.828
# 269       NaN       NaN      NaN   1.755520       201.160       90.383
# 270       NaN  9.715540  5127.84   0.482268       201.188      349.013
#
# [271 rows x 13 columns]

# %% [markdown]
# # Check Nearby Region

# %%
target.calc_depths(tdepth = tdepth, all_ap_pixels = apertures)

target.stars
# Out:
# WARNING: 240968785 is missing stellar properties. If a mass (in M_Sun), radius (in R_Sun), and/or Teff (in K) are not added to the .stars dataframe, Solar values will be assumed.
#             ID     Tmag    Jmag    Hmag    Kmag         ra        dec  \
# 0    240968774  10.5977   9.380   8.791   8.568  19.113929  49.233780
# 1    602264101  20.1211     NaN     NaN     NaN  19.116086  49.234115
# 2    240968773  16.8007  15.770  15.558  14.920  19.107401  49.232925
# 3    602272535  18.6427     NaN     NaN     NaN  19.125483  49.237533
# 4    602272536  18.4817     NaN     NaN     NaN  19.123414  49.239829
# ..         ...      ...     ...     ...     ...        ...        ...
# 266  240968730  16.6550  15.588  14.925  14.994  19.059456  49.191013
# 267  602264145  20.6790     NaN     NaN     NaN  19.032843  49.216625
# 268  602264143  19.3522     NaN     NaN     NaN  19.037341  49.209165
# 269  602272247  19.7174     NaN     NaN     NaN  19.199501  49.233375
# 270  240968835  11.3857  10.467   9.986   9.897  19.097599  49.288640
#
#          mass       rad     Teff        plx  sep (arcsec)  PA (E of N)  \
# 0    0.488826  0.490737  3834.00  26.679300         0.000        0.000
# 1         NaN       NaN      NaN        NaN         5.210       76.635
# 2    0.880000  0.711585  5176.00   0.543496        15.652      258.660
# 3         NaN       NaN  5531.00  -0.309165        30.334       63.546
# 4         NaN       NaN  3444.00   1.693440        31.165       45.667
# ..        ...       ...      ...        ...           ...          ...
# 266  0.770000  0.933857  4758.00   0.526237       200.287      219.783
# 267       NaN       NaN      NaN        NaN       200.398      252.081
# 268       NaN       NaN  4772.00  -0.672445       200.703      243.828
# 269       NaN       NaN      NaN   1.755520       201.160       90.383
# 270       NaN  9.715540  5127.84   0.482268       201.188      349.013
#
#         fluxratio    tdepth
# 0    9.714038e-01  0.001268
# 1    1.508607e-04  0.000000
# 2    2.926168e-03  0.420797
# 3    4.675839e-04  0.000000
# 4    5.036719e-04  0.000000
# ..            ...       ...
# 266  4.025611e-28  0.000000
# 267  1.173032e-31  0.000000
# 268  1.763528e-31  0.000000
# 269  6.471851e-24  0.000000
# 270  9.846137e-23  0.000000
#
# [271 rows x 15 columns]

# %%
for i in range (1, np.size(target.stars['ID'])):
    if target.stars['tdepth'][i] !=0:
        print(i, target.stars['ID'][i])
# Out:
# 2 240968773
# 6 240968785
# 8 240968762
# 17 240968775
# 18 240968782
# 26 240968779
# 36 240968791

# %%
'''target.stars['tdepth'][2] = 0
target.stars['tdepth'][6] = 0
target.stars['tdepth'][8] = 0
target.stars['tdepth'][17] = 0
target.stars['tdepth'][18] = 0
target.stars['tdepth'][26] = 0
target.stars['tdepth'][36] = 0'''
# Out:
# "target.stars['tdepth'][2] = 0\ntarget.stars['tdepth'][6] = 0\ntarget.stars['tdepth'][8] = 0\ntarget.stars['tdepth'][17] = 0\ntarget.stars['tdepth'][18] = 0\ntarget.stars['tdepth'][26] = 0\ntarget.stars['tdepth'][36] = 0"

# %% [markdown]
# # Ploting CC File

# %%
cc = pd.read_csv(contrastcurve_file, header=None)
sep, dmag = cc[0].values, cc[1].values

plt.plot(sep, dmag, 'k-');
plt.ylim(9,0);
plt.ylabel("$\\Delta K_s$", fontsize=20);
plt.xlabel("separation ('')", fontsize=20);

# %% [markdown]
# # Calculating FPP & NFPP

# %%
lc = pd.read_csv(lc_file, header=None)

# read in the light curve
time, flux, flux_err = lc[0].values, lc[1].values, lc[2].values
P_orb = period

lc_binsize = (time.max()-time.min())/100
lc = TessLightCurve(time=time, flux=flux, flux_err=flux_err).bin(time_bin_size=lc_binsize)

plt.scatter(time, flux, s = 5, c = 'c')
plt.scatter(lc.time.value, lc.flux.value, s = 25,  c = 'b')
fig=plt.gcf()
fig.set_size_inches(8,5)

# %%
# %%time
FPPs = np.zeros(6)
NFPPs = np.zeros(6)
for i in range(6):
    target.calc_probs(time = lc.time.value, 
                      flux_0 = lc.flux.value, 
                      flux_err_0 = np.mean(lc.flux_err.value), 
                      P_orb = P_orb,
                      contrast_curve_file = contrastcurve_file,
                      filt = band,
                      exptime = 0.0013888888888889,
                      parallel=True)

    FPPs[i] = target.FPP
    NFPPs[i] = target.NFPP
    print("FPP = ", target.FPP)
    print("NFPP = ", target.NFPP)
# Out:
# Calculating TP scenario probabilitiey for 240968774.
# Calculating EB and EBx2P scenario probabilities for 240968774.
# Calculating PTP scenario probability for 240968774.
# Calculating PEB and PEBx2P scenario probabilities for 240968774.
# Calculating STP scenario probability for 240968774.
# Calculating SEB and SEBx2P scenario probabilities for 240968774.
# Calculating DTP scenario probability for 240968774.
# Calculating DEB and DEBx2P scenario probabilities for 240968774.
# Calculating BTP scenario probability for 240968774.
# Calculating BEB and BEBx2P scenario probabilities for 240968774.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968773.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968785.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968762.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968775.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968782.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968779.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968791.
# FPP =  3.196334470556561e-05
# NFPP =  2.028284989116733e-05
# Calculating TP scenario probabilitiey for 240968774.
# Calculating EB and EBx2P scenario probabilities for 240968774.
# Calculating PTP scenario probability for 240968774.
# Calculating PEB and PEBx2P scenario probabilities for 240968774.
# Calculating STP scenario probability for 240968774.
# Calculating SEB and SEBx2P scenario probabilities for 240968774.
# Calculating DTP scenario probability for 240968774.
# Calculating DEB and DEBx2P scenario probabilities for 240968774.
# Calculating BTP scenario probability for 240968774.
# Calculating BEB and BEBx2P scenario probabilities for 240968774.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968773.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968785.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968762.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968775.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968782.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968779.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968791.
# FPP =  3.475181928302984e-05
# NFPP =  2.219708209668725e-05
# Calculating TP scenario probabilitiey for 240968774.
# Calculating EB and EBx2P scenario probabilities for 240968774.
# Calculating PTP scenario probability for 240968774.
# Calculating PEB and PEBx2P scenario probabilities for 240968774.
# Calculating STP scenario probability for 240968774.
# Calculating SEB and SEBx2P scenario probabilities for 240968774.
# Calculating DTP scenario probability for 240968774.
# Calculating DEB and DEBx2P scenario probabilities for 240968774.
# Calculating BTP scenario probability for 240968774.
# Calculating BEB and BEBx2P scenario probabilities for 240968774.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968773.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968785.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968762.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968775.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968782.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968779.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968791.
# FPP =  4.349502840528263e-05
# NFPP =  2.1944304481358738e-05
# Calculating TP scenario probabilitiey for 240968774.
# Calculating EB and EBx2P scenario probabilities for 240968774.
# Calculating PTP scenario probability for 240968774.
# Calculating PEB and PEBx2P scenario probabilities for 240968774.
# Calculating STP scenario probability for 240968774.
# Calculating SEB and SEBx2P scenario probabilities for 240968774.
# Calculating DTP scenario probability for 240968774.
# Calculating DEB and DEBx2P scenario probabilities for 240968774.
# Calculating BTP scenario probability for 240968774.
# Calculating BEB and BEBx2P scenario probabilities for 240968774.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968773.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968785.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968762.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968775.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968782.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968779.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968791.
# FPP =  4.331964161607971e-05
# NFPP =  2.2519296677849102e-05
# Calculating TP scenario probabilitiey for 240968774.
# Calculating EB and EBx2P scenario probabilities for 240968774.
# Calculating PTP scenario probability for 240968774.
# Calculating PEB and PEBx2P scenario probabilities for 240968774.
# Calculating STP scenario probability for 240968774.
# Calculating SEB and SEBx2P scenario probabilities for 240968774.
# Calculating DTP scenario probability for 240968774.
# Calculating DEB and DEBx2P scenario probabilities for 240968774.
# Calculating BTP scenario probability for 240968774.
# Calculating BEB and BEBx2P scenario probabilities for 240968774.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968773.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968785.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968762.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968775.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968782.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968779.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968791.
# FPP =  3.4208811807934225e-05
# NFPP =  2.258969274255024e-05
# Calculating TP scenario probabilitiey for 240968774.
# Calculating EB and EBx2P scenario probabilities for 240968774.
# Calculating PTP scenario probability for 240968774.
# Calculating PEB and PEBx2P scenario probabilities for 240968774.
# Calculating STP scenario probability for 240968774.
# Calculating SEB and SEBx2P scenario probabilities for 240968774.
# Calculating DTP scenario probability for 240968774.
# Calculating DEB and DEBx2P scenario probabilities for 240968774.
# Calculating BTP scenario probability for 240968774.
# Calculating BEB and BEBx2P scenario probabilities for 240968774.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968773.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968785.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968762.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968775.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968782.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968779.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968791.
# FPP =  3.796404285549837e-05
# NFPP =  1.8527247726314103e-05
# CPU times: total: 1h 8min 17s
# Wall time: 9min 13s

# %%
df_results = target.probs
print("FPP = ", target.FPP)
print("NFPP = ", target.NFPP)
df_results
# Out:
# FPP =  3.796404285549837e-05
# NFPP =  1.8527247726314103e-05
#            ID scenario       M_s       R_s      P_orb        inc         b  \
# 0   240968774       TP  0.488826  0.490737   5.971142  89.870996  0.054918
# 1   240968774       EB  0.488826  0.490737   5.971142  85.934214  1.920456
# 2   240968774    EBx2P  0.488826  0.490737  11.942285  88.429264  0.735029
# 3   240968774      PTP  0.488826  0.490737   5.971142  88.977474  0.384771
# 4   240968774      PEB  0.488826  0.490737   5.971142  85.431570  1.751596
# 5   240968774   PEBx2P  0.488826  0.490737  11.942285  87.665803  1.526523
# 6   240968774      STP  0.433306  0.432290   5.971142  89.380809  0.217525
# 7   240968774      SEB  0.106288  0.128853   5.971142  88.581092  1.363234
# 8   240968774   SEBx2P  0.349937  0.359947  11.942285  88.700168  0.852832
# 9   240968774      DTP  0.488826  0.490737   5.971142  89.418482  0.207406
# 10  240968774      DEB  0.488826  0.490737   5.971142  85.851740  1.885533
# 11  240968774   DEBx2P  0.488826  0.490737  11.942285  88.493570  0.548122
# 12  240968774      BTP  0.523000  0.459499   5.971142  88.752497  0.386289
# 13  240968774      BEB  0.473000  0.422148   5.971142  89.791700  0.094587
# 14  240968774   BEBx2P  0.523000  0.459499  11.942285  88.330718  1.412399
# 15  240968773      NTP  0.880000  0.711585   5.971142  89.631197  0.123979
# 16  240968773      NEB  0.880000  0.711585   5.971142  89.864731  0.073802
# 17  240968773   NEBx2P  0.880000  0.711585  11.942285  89.572345  0.227936
# 18  240968785      NTP  1.000000  1.000000   5.971142  89.288601  0.137261
# 19  240968785      NEB  1.000000  1.000000   5.971142  89.884548  0.039124
# 20  240968785   NEBx2P  1.000000  1.000000  11.942285  89.909786  0.019956
# 21  240968762      NTP  0.970000  0.957065   5.971142  89.695139  0.095424
# 22  240968762      NEB  0.970000  0.957065   5.971142  89.829535  0.030413
# 23  240968762   NEBx2P  0.970000  0.957065  11.942285  89.817243  0.009032
# 24  240968775      NTP  0.770000  0.869846   5.971142  89.917926  0.017238
# 25  240968775      NEB  0.770000  0.869846   5.971142  89.957003  0.006928
# 26  240968775   NEBx2P  0.770000  0.869846  11.942285  89.885355  0.075988
# 27  240968782      NTP  1.030000  1.584210   5.971142  89.571302  0.073427
# 28  240968782      NEB  1.030000  1.584210   5.971142  84.134643  0.490230
# 29  240968782   NEBx2P  1.030000  1.584210  11.942285  80.046152  1.267792
# 30  240968779      NTP  0.840000  0.979185   5.971142  89.622809  0.062489
# 31  240968779      NEB  0.840000  0.979185   5.971142  89.941879  0.022340
# 32  240968779   NEBx2P  0.840000  0.979185  11.942285  89.974117  0.011592
# 33  240968791      NTP  1.030000  1.470230   5.971142  86.908968  0.359459
# 34  240968791      NEB  1.030000  1.470230   5.971142  89.655262  0.129541
# 35  240968791   NEBx2P  1.030000  1.470230  11.942285  89.953259  0.020773
#
#              ecc           w        R_p      M_EB      R_EB          prob
# 0   3.620658e-01  324.945723   1.868864  0.000000  0.000000  9.351888e-01
# 1   4.858066e-02   25.937941   0.000000  0.459228  0.457779  6.255598e-28
# 2   5.868847e-01  172.270841   0.000000  0.466879  0.465757  2.281246e-07
# 3   2.779924e-01  349.952254   1.940312  0.000000  0.000000  9.782540e-06
# 4   2.286736e-01   58.785169   0.000000  0.460831  0.459432  9.011536e-30
# 5   7.445291e-01  219.606926   0.000000  0.470069  0.469153  4.607792e-15
# 6   2.491890e-01   31.372930   2.528140  0.000000  0.000000  9.405061e-13
# 7   4.122976e-08   98.485624   0.000000  0.028052  0.100000  7.944994e-25
# 8   6.497632e-01  195.404423   0.000000  0.334664  0.347160  1.550892e-09
# 9   3.019803e-01  357.868769   1.857772  0.000000  0.000000  6.476347e-02
# 10  8.330454e-02   40.932447   0.000000  0.454450  0.452910  1.758820e-29
# 11  6.859405e-01  169.845475   0.000000  0.467349  0.466255  7.555396e-09
# 12  2.773113e-01  108.151070  18.937154  0.000000  0.000000  2.285729e-06
# 13  7.314612e-02   94.162978   0.000000  0.152887  0.184628  1.312890e-05
# 14  6.668492e-06  291.362457   0.000000  0.517381  0.459499  3.784937e-06
# 15  4.094563e-02  305.809362  19.885860  0.000000  0.000000  8.365362e-31
# 16  5.011887e-01  284.801440   0.000000  0.470991  0.470141  5.185832e-06
# 17  4.964233e-01  349.912050   0.000000  0.837308  0.711585  5.315098e-07
# 18  2.075079e-01   73.463559  19.987585  0.000000  0.000000  1.190360e-36
# 19  4.588556e-01  315.724129   0.000000  0.757838  0.787617  1.404945e-08
# 20  6.162423e-01   34.115729   0.000000  0.955860  1.000000  1.480985e-09
# 21  2.795953e-01  289.455128  19.961321  0.000000  0.000000  1.056387e-37
# 22  4.395241e-01   55.227278   0.000000  0.721710  0.753012  5.452140e-10
# 23  9.015615e-01  103.034988   0.000000  0.921960  0.957065  1.797231e-11
# 24  1.754753e-01   90.506115  19.909071  0.000000  0.000000  1.110772e-35
# 25  5.016998e-01   63.234861   0.000000  0.642006  0.663685  4.430120e-09
# 26  6.060270e-01  301.330498   0.000000  0.732422  0.763510  2.264684e-10
# 27  5.933143e-01  315.345954  19.971966  0.000000  0.000000  2.036615e-35
# 28  7.599176e-01  354.595004   0.000000  0.722450  0.753747  1.065586e-05
# 29  8.323034e-01  341.336182   0.000000  0.978873  1.048352  2.133281e-06
# 30  3.165400e-01   56.903422  19.791327  0.000000  0.000000  1.505546e-37
# 31  4.919909e-01  295.839398   0.000000  0.659307  0.684646  1.637725e-11
# 32  5.559503e-01  328.947956   0.000000  0.801747  0.828689  6.889364e-13
# 33  4.136276e-01   26.265007  19.995077  0.000000  0.000000  1.763440e-38
# 34  8.414603e-01  268.487463   0.000000  0.892094  0.927132  9.581226e-16
# 35  8.160756e-01  292.875987   0.000000  0.993084  1.069148  1.792176e-14

# %%
target.plot_fits(time=time, flux_0=flux, flux_err_0=np.mean(flux_err))

# %%
for i in range (len(FPPs)):
    print(FPPs[i],",")

print("NFPPs:")
for i in range (len(FPPs)):
    print(NFPPs[i],",")
# Out:
# 3.196334470556561e-05 ,
# 3.475181928302984e-05 ,
# 4.349502840528263e-05 ,
# 4.331964161607971e-05 ,
# 3.4208811807934225e-05 ,
# 3.796404285549837e-05 ,
# NFPPs:
# 2.028284989116733e-05 ,
# 2.219708209668725e-05 ,
# 2.1944304481358738e-05 ,
# 2.2519296677849102e-05 ,
# 2.258969274255024e-05 ,
# 1.8527247726314103e-05 ,

# %% [markdown]
# ### Tess NFPP run

# %%
ID = 240968774
sectors = np.array([17,18])

period = 5.9711424562
tdepth = 0.001231323616846885

lc_file = "TOI_1467_S17_18_58.csv"
contrastcurve_file = "TOI_1467_832nm.csv"

band = 'TESS'

# %%
cc = pd.read_csv(contrastcurve_file, header=None)
sep, dmag = cc[0].values, cc[1].values

plt.plot(sep, dmag, 'k-');
plt.ylim(9,0);
plt.ylabel("$\\Delta K_s$", fontsize=20);
plt.xlabel("separation ('')", fontsize=20);

# %%
lc = pd.read_csv(lc_file, header=None)

# read in the light curve
time, flux, flux_err = lc[0].values, lc[1].values, lc[2].values
P_orb = period

lc_binsize = (time.max()-time.min())/100
lc = TessLightCurve(time=time, flux=flux, flux_err=flux_err).bin(time_bin_size=lc_binsize)

plt.scatter(time, flux, s = 5, c = 'c')
plt.scatter(lc.time.value, lc.flux.value, s = 25,  c = 'b')
fig=plt.gcf()
fig.set_size_inches(8,5)

# %%
# %%time
FPPs = np.zeros(6)
NFPPs = np.zeros(6)
for i in range(6):
    target.calc_probs(time = lc.time.value, 
                      flux_0 = lc.flux.value, 
                      flux_err_0 = np.mean(lc.flux_err.value), 
                      P_orb = P_orb,
                      contrast_curve_file = contrastcurve_file,
                      filt = band,
                      exptime = 0.0013888888888889,
                      parallel=True)

    FPPs[i] = target.FPP
    NFPPs[i] = target.NFPP
    print("FPP = ", target.FPP)
    print("NFPP = ", target.NFPP)
# Out:
# Calculating TP scenario probabilitiey for 240968774.
# Calculating EB and EBx2P scenario probabilities for 240968774.
# Calculating PTP scenario probability for 240968774.
# Calculating PEB and PEBx2P scenario probabilities for 240968774.
# Calculating STP scenario probability for 240968774.
# Calculating SEB and SEBx2P scenario probabilities for 240968774.
# Calculating DTP scenario probability for 240968774.
# Calculating DEB and DEBx2P scenario probabilities for 240968774.
# Calculating BTP scenario probability for 240968774.
# Calculating BEB and BEBx2P scenario probabilities for 240968774.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968773.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968785.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968762.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968775.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968782.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968779.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968791.
# FPP =  2.6843671025233995e-05
# NFPP =  2.3913138059715996e-05
# Calculating TP scenario probabilitiey for 240968774.
# Calculating EB and EBx2P scenario probabilities for 240968774.
# Calculating PTP scenario probability for 240968774.
# Calculating PEB and PEBx2P scenario probabilities for 240968774.
# Calculating STP scenario probability for 240968774.
# Calculating SEB and SEBx2P scenario probabilities for 240968774.
# Calculating DTP scenario probability for 240968774.
# Calculating DEB and DEBx2P scenario probabilities for 240968774.
# Calculating BTP scenario probability for 240968774.
# Calculating BEB and BEBx2P scenario probabilities for 240968774.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968773.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968785.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968762.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968775.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968782.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968779.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968791.
# FPP =  2.2762517376984093e-05
# NFPP =  1.976833568619936e-05
# Calculating TP scenario probabilitiey for 240968774.
# Calculating EB and EBx2P scenario probabilities for 240968774.
# Calculating PTP scenario probability for 240968774.
# Calculating PEB and PEBx2P scenario probabilities for 240968774.
# Calculating STP scenario probability for 240968774.
# Calculating SEB and SEBx2P scenario probabilities for 240968774.
# Calculating DTP scenario probability for 240968774.
# Calculating DEB and DEBx2P scenario probabilities for 240968774.
# Calculating BTP scenario probability for 240968774.
# Calculating BEB and BEBx2P scenario probabilities for 240968774.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968773.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968785.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968762.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968775.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968782.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968779.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968791.
# FPP =  2.8263254146954075e-05
# NFPP =  2.3687961526266233e-05
# Calculating TP scenario probabilitiey for 240968774.
# Calculating EB and EBx2P scenario probabilities for 240968774.
# Calculating PTP scenario probability for 240968774.
# Calculating PEB and PEBx2P scenario probabilities for 240968774.
# Calculating STP scenario probability for 240968774.
# Calculating SEB and SEBx2P scenario probabilities for 240968774.
# Calculating DTP scenario probability for 240968774.
# Calculating DEB and DEBx2P scenario probabilities for 240968774.
# Calculating BTP scenario probability for 240968774.
# Calculating BEB and BEBx2P scenario probabilities for 240968774.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968773.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968785.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968762.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968775.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968782.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968779.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968791.
# FPP =  2.871522730740761e-05
# NFPP =  2.076977011955236e-05
# Calculating TP scenario probabilitiey for 240968774.
# Calculating EB and EBx2P scenario probabilities for 240968774.
# Calculating PTP scenario probability for 240968774.
# Calculating PEB and PEBx2P scenario probabilities for 240968774.
# Calculating STP scenario probability for 240968774.
# Calculating SEB and SEBx2P scenario probabilities for 240968774.
# Calculating DTP scenario probability for 240968774.
# Calculating DEB and DEBx2P scenario probabilities for 240968774.
# Calculating BTP scenario probability for 240968774.
# Calculating BEB and BEBx2P scenario probabilities for 240968774.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968773.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968785.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968762.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968775.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968782.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968779.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968791.
# FPP =  2.6252699744322427e-05
# NFPP =  2.2656817345395878e-05
# Calculating TP scenario probabilitiey for 240968774.
# Calculating EB and EBx2P scenario probabilities for 240968774.
# Calculating PTP scenario probability for 240968774.
# Calculating PEB and PEBx2P scenario probabilities for 240968774.
# Calculating STP scenario probability for 240968774.
# Calculating SEB and SEBx2P scenario probabilities for 240968774.
# Calculating DTP scenario probability for 240968774.
# Calculating DEB and DEBx2P scenario probabilities for 240968774.
# Calculating BTP scenario probability for 240968774.
# Calculating BEB and BEBx2P scenario probabilities for 240968774.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968773.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968785.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968762.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968775.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968782.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968779.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968791.
# FPP =  3.69212692881149e-05
# NFPP =  2.6199860672777176e-05
# CPU times: total: 1h 14min 31s
# Wall time: 9min 41s

# %%
for i in range (len(FPPs)):
    print(FPPs[i],",")

print("NFPPs:")
for i in range (len(FPPs)):
    print(NFPPs[i],",")
# Out:
# 2.6843671025233995e-05 ,
# 2.2762517376984093e-05 ,
# 2.8263254146954075e-05 ,
# 2.871522730740761e-05 ,
# 2.6252699744322427e-05 ,
# 3.69212692881149e-05 ,
# NFPPs:
# 2.3913138059715996e-05 ,
# 1.976833568619936e-05 ,
# 2.3687961526266233e-05 ,
# 2.076977011955236e-05 ,
# 2.2656817345395878e-05 ,
# 2.6199860672777176e-05 ,

# %% [markdown]
# ### K filter

# %%
ID = 240968774
sectors = np.array([17,18])

period = 5.9711424562
tdepth = 0.001231323616846885

lc_file = "TOI_1467_S17_18_58.csv"
contrastcurve_file = "TOI_1467_K.csv"

band = 'K'

# %%
cc = pd.read_csv(contrastcurve_file, header=None)
sep, dmag = cc[0].values, cc[1].values

plt.plot(sep, dmag, 'k-');
plt.ylim(9,0);
plt.ylabel("$\\Delta K_s$", fontsize=20);
plt.xlabel("separation ('')", fontsize=20);

# %%
lc = pd.read_csv(lc_file, header=None)

# read in the light curve
time, flux, flux_err = lc[0].values, lc[1].values, lc[2].values
P_orb = period

lc_binsize = (time.max()-time.min())/100
lc = TessLightCurve(time=time, flux=flux, flux_err=flux_err).bin(time_bin_size=lc_binsize)

plt.scatter(time, flux, s = 5, c = 'c')
plt.scatter(lc.time.value, lc.flux.value, s = 25,  c = 'b')
fig=plt.gcf()
fig.set_size_inches(8,5)

# %%
# %%time
FPPs = np.zeros(6)
NFPPs = np.zeros(6)
for i in range(6):
    target.calc_probs(time = lc.time.value, 
                      flux_0 = lc.flux.value, 
                      flux_err_0 = np.mean(lc.flux_err.value), 
                      P_orb = P_orb,
                      contrast_curve_file = contrastcurve_file,
                      filt = band,
                      exptime = 0.0013888888888889,
                      parallel=True)

    FPPs[i] = target.FPP
    NFPPs[i] = target.NFPP
    print("FPP = ", target.FPP)
    print("NFPP = ", target.NFPP)
# Out:
# Calculating TP scenario probabilitiey for 240968774.
# Calculating EB and EBx2P scenario probabilities for 240968774.
# Calculating PTP scenario probability for 240968774.
# Calculating PEB and PEBx2P scenario probabilities for 240968774.
# Calculating STP scenario probability for 240968774.
# Calculating SEB and SEBx2P scenario probabilities for 240968774.
# Calculating DTP scenario probability for 240968774.
# Calculating DEB and DEBx2P scenario probabilities for 240968774.
# Calculating BTP scenario probability for 240968774.
# Calculating BEB and BEBx2P scenario probabilities for 240968774.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968773.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968785.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968762.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968775.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968782.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968779.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968791.
# FPP =  2.2783485003619042e-05
# NFPP =  2.0110995968590097e-05
# Calculating TP scenario probabilitiey for 240968774.
# Calculating EB and EBx2P scenario probabilities for 240968774.
# Calculating PTP scenario probability for 240968774.
# Calculating PEB and PEBx2P scenario probabilities for 240968774.
# Calculating STP scenario probability for 240968774.
# Calculating SEB and SEBx2P scenario probabilities for 240968774.
# Calculating DTP scenario probability for 240968774.
# Calculating DEB and DEBx2P scenario probabilities for 240968774.
# Calculating BTP scenario probability for 240968774.
# Calculating BEB and BEBx2P scenario probabilities for 240968774.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968773.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968785.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968762.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968775.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968782.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968779.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968791.
# FPP =  2.532555984791074e-05
# NFPP =  1.9563562661324863e-05
# Calculating TP scenario probabilitiey for 240968774.
# Calculating EB and EBx2P scenario probabilities for 240968774.
# Calculating PTP scenario probability for 240968774.
# Calculating PEB and PEBx2P scenario probabilities for 240968774.
# Calculating STP scenario probability for 240968774.
# Calculating SEB and SEBx2P scenario probabilities for 240968774.
# Calculating DTP scenario probability for 240968774.
# Calculating DEB and DEBx2P scenario probabilities for 240968774.
# Calculating BTP scenario probability for 240968774.
# Calculating BEB and BEBx2P scenario probabilities for 240968774.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968773.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968785.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968762.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968775.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968782.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968779.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968791.
# FPP =  2.3985743903720547e-05
# NFPP =  2.034421247031775e-05
# Calculating TP scenario probabilitiey for 240968774.
# Calculating EB and EBx2P scenario probabilities for 240968774.
# Calculating PTP scenario probability for 240968774.
# Calculating PEB and PEBx2P scenario probabilities for 240968774.
# Calculating STP scenario probability for 240968774.
# Calculating SEB and SEBx2P scenario probabilities for 240968774.
# Calculating DTP scenario probability for 240968774.
# Calculating DEB and DEBx2P scenario probabilities for 240968774.
# Calculating BTP scenario probability for 240968774.
# Calculating BEB and BEBx2P scenario probabilities for 240968774.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968773.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968785.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968762.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968775.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968782.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968779.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968791.
# FPP =  2.214294262481431e-05
# NFPP =  1.793776340849281e-05
# Calculating TP scenario probabilitiey for 240968774.
# Calculating EB and EBx2P scenario probabilities for 240968774.
# Calculating PTP scenario probability for 240968774.
# Calculating PEB and PEBx2P scenario probabilities for 240968774.
# Calculating STP scenario probability for 240968774.
# Calculating SEB and SEBx2P scenario probabilities for 240968774.
# Calculating DTP scenario probability for 240968774.
# Calculating DEB and DEBx2P scenario probabilities for 240968774.
# Calculating BTP scenario probability for 240968774.
# Calculating BEB and BEBx2P scenario probabilities for 240968774.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968773.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968785.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968762.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968775.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968782.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968779.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968791.
# FPP =  2.2709584332925026e-05
# NFPP =  1.9615404346848783e-05
# Calculating TP scenario probabilitiey for 240968774.
# Calculating EB and EBx2P scenario probabilities for 240968774.
# Calculating PTP scenario probability for 240968774.
# Calculating PEB and PEBx2P scenario probabilities for 240968774.
# Calculating STP scenario probability for 240968774.
# Calculating SEB and SEBx2P scenario probabilities for 240968774.
# Calculating DTP scenario probability for 240968774.
# Calculating DEB and DEBx2P scenario probabilities for 240968774.
# Calculating BTP scenario probability for 240968774.
# Calculating BEB and BEBx2P scenario probabilities for 240968774.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968773.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968785.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968762.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968775.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968782.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968779.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 240968791.
# FPP =  2.0958925959990715e-05
# NFPP =  1.797913467244108e-05
# CPU times: total: 1h 45min 23s
# Wall time: 13min 13s

# %%
for i in range (len(FPPs)):
    print(FPPs[i],",")

print("NFPPs:")
for i in range (len(FPPs)):
    print(NFPPs[i],",")
# Out:
# 2.2783485003619042e-05 ,
# 2.532555984791074e-05 ,
# 2.3985743903720547e-05 ,
# 2.214294262481431e-05 ,
# 2.2709584332925026e-05 ,
# 2.0958925959990715e-05 ,
# NFPPs:
# 2.0110995968590097e-05 ,
# 1.9563562661324863e-05 ,
# 2.034421247031775e-05 ,
# 1.793776340849281e-05 ,
# 1.9615404346848783e-05 ,
# 1.797913467244108e-05 ,

# %% [markdown]
# ### Result Log in

# %%
##Vis 562nm

fpp=np.array([3.196334470556561e-05 ,
3.475181928302984e-05 ,
4.349502840528263e-05 ,
4.331964161607971e-05 ,
3.4208811807934225e-05 ,
3.796404285549837e-05])
nfpp=np.array([2.028284989116733e-05 ,
2.219708209668725e-05 ,
2.1944304481358738e-05 ,
2.2519296677849102e-05 ,
2.258969274255024e-05 ,
1.8527247726314103e-05])

print(np.mean(fpp),"+/-",np.std(fpp))
print(np.mean(nfpp),"+/-",np.std(nfpp))
# Out:
# 3.76171147788984e-05 +/- 4.453100108931252e-06
# 2.1343412269321125e-05 +/- 1.4765566969619626e-06

# %%
##Tess 832nm

fpp=np.array([2.6843671025233995e-05 ,
2.2762517376984093e-05 ,
2.8263254146954075e-05 ,
2.871522730740761e-05 ,
2.6252699744322427e-05 ,
3.69212692881149e-05])
nfpp=np.array([2.3913138059715996e-05 ,
1.976833568619936e-05 ,
2.3687961526266233e-05 ,
2.076977011955236e-05 ,
2.2656817345395878e-05 ,
2.6199860672777176e-05])

print(np.mean(fpp),"+/-",np.std(fpp))
print(np.mean(nfpp),"+/-",np.std(nfpp))
# Out:
# 2.829310648150285e-05 +/- 4.310371391751647e-06
# 2.2832647234984504e-05 +/- 2.1179208635796433e-06

# %%
##K filter

fpp=np.array([2.2783485003619042e-05 ,
2.532555984791074e-05 ,
2.3985743903720547e-05 ,
2.214294262481431e-05 ,
2.2709584332925026e-05 ,
2.0958925959990715e-05])
nfpp=np.array([2.0110995968590097e-05 ,
1.9563562661324863e-05 ,
2.034421247031775e-05 ,
1.793776340849281e-05 ,
1.9615404346848783e-05 ,
1.797913467244108e-05])

print(np.mean(fpp),"+/-",np.std(fpp))
print(np.mean(nfpp),"+/-",np.std(nfpp))
# Out:
# 2.2984373612163395e-05 +/- 1.3790217021773308e-06
# 1.9258512254669232e-05 +/- 9.580436376112965e-07
