# 25  0.970000  0.683637  5508.0   0.408634       153.960      321.111
# 26  0.870000  0.499804  5167.0   0.443674       157.869      307.893
# 27  0.246202  0.273053  3198.0   3.472210       159.502      217.431
# 28       NaN       NaN     NaN  -0.819891       159.672       76.925
# 29       NaN       NaN     NaN   2.919620       163.801      316.771
# 30       NaN       NaN     NaN        NaN       163.975      320.148
# 31       NaN       NaN     NaN        NaN       164.634      156.443
# 32       NaN       NaN  3400.0   2.679270       184.838       57.864
# 33  0.730000  0.640558  4621.0   1.104600       192.847      235.283
# 34  0.920000  0.855334  5347.0   2.180760       197.385       25.739
#
#        fluxratio    tdepth
# 0   9.718094e-01  0.000402
# 1   2.713824e-02  0.014412
# 2   1.443391e-04  0.000000
# 3   2.730506e-05  0.000000
# 4   6.912837e-05  0.000000
# 5   7.545059e-04  0.518375
# 6   2.312236e-05  0.000000
# 7   2.426859e-06  0.000000
# 8   1.608797e-05  0.000000
# 9   1.085708e-05  0.000000
# 10  6.264194e-07  0.000000
# 11  4.195096e-08  0.000000
# 12  1.111171e-06  0.000000
# 13  2.717370e-06  0.000000
# 14  3.836315e-08  0.000000
# 15  4.552949e-09  0.000000
# 16  3.162780e-10  0.000000
# 17  1.685999e-10  0.000000
# 18  4.172445e-10  0.000000
# 19  1.573798e-08  0.000000
# 20  2.993387e-11  0.000000
# 21  9.888139e-12  0.000000
# 22  4.083675e-11  0.000000
# 23  2.097926e-13  0.000000
# 24  1.528834e-14  0.000000
# 25  2.129157e-14  0.000000
# 26  4.612982e-15  0.000000
# 27  4.972229e-15  0.000000
# 28  8.824639e-16  0.000000
# 29  2.284034e-17  0.000000
# 30  8.285379e-18  0.000000
# 31  5.538008e-16  0.000000
# 32  4.005666e-21  0.000000
# 33  2.048235e-22  0.000000
# 34  6.775797e-23  0.000000

# %%
for i in range (1, np.size(target.stars['ID'])):
    if target.stars['tdepth'][i] !=0:
        print(i, target.stars['ID'][i])
# Out:
# 1 9006666
# 5 10000007152

# %%
target.stars['tdepth'][1] = 0
target.stars['tdepth'][5] = 0

# %% [markdown]
# # Ploting CC File

# %%
cc = pd.read_csv(contrastcurve_file, header=None)
sep, dmag = cc[0].values, cc[1].values

plt.plot(sep, dmag, 'k-');
plt.ylim(11,0);
plt.ylabel("$\\Delta K_s$", fontsize=20);
plt.xlabel("separation ('')", fontsize=20);

# %% [markdown]
# # Calculating FPP & NFPP

# %%
# %%time

lc = pd.read_csv(lc_file, header=None)

# read in the light curve
time, flux, flux_err = lc[0].values, lc[1].values, lc[2].values
P_orb = period

lc_binsize = (time.max()-time.min())/200
lc = TessLightCurve(time=time, flux=flux, flux_err=flux_err).bin(time_bin_size=lc_binsize)

plt.scatter(time, flux, s = 5, c = 'c')
plt.scatter(lc.time.value, lc.flux.value, s = 25,  c = 'b')
fig=plt.gcf()
fig.set_size_inches(8,5)
# Out:
# Wall time: 91 ms

# %%
for i in range(20):
    target.calc_probs(time = lc.time.value, 
                      flux_0 = lc.flux.value, 
                      flux_err_0 = np.mean(lc.flux_err.value), 
                      P_orb = P_orb,
                      contrast_curve_file = contrastcurve_file,
                      filt = band,
                      exptime = 0.0013888888888889)

    print("FPP = ", target.FPP)
    print("NFPP = ", target.NFPP)
# Out:
# Calculating TP scenario probabilitiey for 9006668.
# Calculating EB and EBx2P scenario probabilities for 9006668.
# Calculating PTP scenario probability for 9006668.
# Calculating PEB and PEBx2P scenario probabilities for 9006668.
# Calculating STP scenario probability for 9006668.
# Calculating SEB and SEBx2P scenario probabilities for 9006668.
# Calculating DTP scenario probability for 9006668.
# Calculating DEB and DEBx2P scenario probabilities for 9006668.
# Calculating BTP scenario probability for 9006668.
# Calculating BEB and BEBx2P scenario probabilities for 9006668.

# %%
df_results = target.probs
print("FPP = ", target.FPP)
print("NFPP = ", target.NFPP)
df_results
# Out:
# FPP =  0.0029230835846509873
# NFPP =  0.0
#          ID scenario       M_s       R_s     P_orb        inc         b  \
# 0   9006668       TP  0.840000  0.766028  1.273114  84.445571  0.570547
# 1   9006668       EB  0.840000  0.766028  1.273114  54.678447  1.315848
# 2   9006668    EBx2P  0.840000  0.766028  2.546228  84.213458  0.581436
# 3   9006668      PTP  0.840000  0.766028  1.273114  84.444373  0.630510
# 4   9006668      PEB  0.840000  0.766028  1.273114  59.090784  1.287824
# 5   9006668   PEBx2P  0.840000  0.766028  2.546228  82.826010  0.955032
# 6   9006668      STP  0.586315  0.589126  1.273114  89.339321  0.081186
# 7   9006668      SEB  0.162172  0.194153  1.273114  87.408460  0.116365
# 8   9006668   SEBx2P  0.360756  0.368979  2.546228  86.727084  0.458311
# 9   9006668      DTP  0.840000  0.766028  1.273114  84.551047  0.617003
# 10  9006668      DEB  0.840000  0.766028  1.273114  74.777401  1.978817
# 11  9006668   DEBx2P  0.840000  0.766028  2.546228  84.136232  0.828075
# 12  9006668      BTP  0.764000  0.704824  1.273114  89.931199  0.008819
# 13  9006668      BEB  0.932000  0.956625  1.273114  83.760014  0.775728
# 14  9006668   BEBx2P  0.764000  0.901738  2.546228  81.426089  1.494104
#
#          ecc           w        R_p      M_EB      R_EB          prob
# 0   0.157052  177.275518   1.750565  0.000000  0.000000  8.382408e-01
# 1   0.694714   86.264838   0.000000  0.697772  0.728414  8.756302e-46
# 2   0.783262  193.746180   0.000000  0.826058  0.766028  3.755334e-21
# 3   0.150569  214.965254   1.765293  0.000000  0.000000  3.967230e-02
# 4   0.668058   88.910015   0.000000  0.762873  0.766028  6.489593e-43
# 5   0.762639  206.317365   0.000000  0.807444  0.766028  1.611566e-34
# 6   0.004592  326.153798   3.585952  0.000000  0.000000  2.074754e-03
# 7   0.892742  166.792855   0.000000  0.053244  0.100000  6.745725e-08
# 8   0.739270  174.269994   0.000000  0.353340  0.362788  1.107078e-10
# 9   0.135648  216.222367   1.715591  0.000000  0.000000  1.191638e-01
# 10  0.000002  280.073453   0.000000  0.752818  0.766028  6.888210e-48
# 11  0.639140  190.597835   0.000000  0.804975  0.766028  4.453380e-34
# 12  0.146480  275.906499  14.084366  0.000000  0.000000  5.337095e-05
# 13  0.370202  279.539689   0.000000  0.117288  0.143481  7.847019e-04
# 14  0.001665  177.613855   0.000000  0.763801  0.793178  1.018902e-05

# %%
target.plot_fits(time=time, flux_0=flux, flux_err_0=np.mean(flux_err))

# %%
# BrGamma

FPP = np.array([])

print("Mean FPP = ",np.round(np.mean(FPP),3))
print("Standard Deviation FPP = ",np.round(np.std(FPP),3))
# Out:
# Mean FPP =  nan
# Standard Deviation FPP =  nan

# %%
# 562nm (24/08/2020)

FPP = np.array([])

print("Mean FPP = ",np.round(np.mean(FPP),3))
print("Standard Deviation FPP = ",np.round(np.stdev(FPP),3))

# %%
# 562nm (10/09/2020)

FPP = np.array([])

print("Mean FPP = ",np.round(np.mean(FPP),3))
print("Standard Deviation FPP = ",np.round(np.stdev(FPP),3))

# %%
# 832nm (24/08/2020)

FPP = np.array([])

print("Mean FPP = ",np.round(np.mean(FPP),3))
print("Standard Deviation FPP = ",np.round(np.stdev(FPP),3))

# %%
# 832nm (10/09/2020)

FPP = np.array([])

print("Mean FPP = ",np.round(np.mean(FPP),3))
print("Standard Deviation FPP = ",np.round(np.stdev(FPP),3))
