# 29       NaN       NaN     NaN   2.919620       163.801      316.771
# 30       NaN       NaN     NaN        NaN       163.975      320.148
# 31       NaN       NaN     NaN        NaN       164.634      156.443
# 32       NaN       NaN  3400.0   2.679270       184.838       57.864
# 33  0.730000  0.640558  4621.0   1.104600       192.847      235.283
# 34  0.920000  0.855334  5347.0   2.180760       197.385       25.739
#
#        fluxratio    tdepth
# 0   9.718094e-01  0.000402
# 1   2.713824e-02  0.014412
# 2   1.443391e-04  0.000000
# 3   2.730506e-05  0.000000
# 4   6.912837e-05  0.000000
# 5   7.545059e-04  0.518375
# 6   2.312236e-05  0.000000
# 7   2.426859e-06  0.000000
# 8   1.608797e-05  0.000000
# 9   1.085708e-05  0.000000
# 10  6.264194e-07  0.000000
# 11  4.195096e-08  0.000000
# 12  1.111171e-06  0.000000
# 13  2.717370e-06  0.000000
# 14  3.836315e-08  0.000000
# 15  4.552949e-09  0.000000
# 16  3.162780e-10  0.000000
# 17  1.685999e-10  0.000000
# 18  4.172445e-10  0.000000
# 19  1.573798e-08  0.000000
# 20  2.993387e-11  0.000000
# 21  9.888139e-12  0.000000
# 22  4.083675e-11  0.000000
# 23  2.097926e-13  0.000000
# 24  1.528834e-14  0.000000
# 25  2.129157e-14  0.000000
# 26  4.612982e-15  0.000000
# 27  4.972229e-15  0.000000
# 28  8.824639e-16  0.000000
# 29  2.284034e-17  0.000000
# 30  8.285379e-18  0.000000
# 31  5.538008e-16  0.000000
# 32  4.005666e-21  0.000000
# 33  2.048235e-22  0.000000
# 34  6.775797e-23  0.000000

# %%
for i in range (1, np.size(target.stars['ID'])):
    if target.stars['tdepth'][i] !=0:
        print(i, target.stars['ID'][i])
# Out:
# 1 9006666
# 5 10000007152

# %%
'''target.stars['tdepth'][1] = 0
target.stars['tdepth'][5] = 0
'''
# Out:
# "target.stars['tdepth'][1] = 0\ntarget.stars['tdepth'][5] = 0\n"

# %% [markdown]
# # Ploting CC File

# %%
cc = pd.read_csv(contrastcurve_file, header=None)
sep, dmag = cc[0].values, cc[1].values

plt.plot(sep, dmag, 'k-');
plt.ylim(11,0);
plt.ylabel("$\\Delta K_s$", fontsize=20);
plt.xlabel("separation ('')", fontsize=20);

# %% [markdown]
# # Calculating FPP & NFPP

# %%
# %%time

lc = pd.read_csv(lc_file, header=None)

# read in the light curve
time, flux, flux_err = lc[0].values, lc[1].values, lc[2].values
P_orb = period

lc_binsize = (time.max()-time.min())/200
lc = TessLightCurve(time=time, flux=flux, flux_err=flux_err).bin(time_bin_size=lc_binsize)

plt.scatter(time, flux, s = 5, c = 'c')
plt.scatter(lc.time.value, lc.flux.value, s = 25,  c = 'b')
fig=plt.gcf()
fig.set_size_inches(8,5)
# Out:
# CPU times: total: 2.67 s
# Wall time: 2.71 s

# %%
FPPs = np.zeros(5)
NFPPs = np.zeros(5)
for i in range(5):
    target.calc_probs(time = lc.time.value, 
                      flux_0 = lc.flux.value, 
                      flux_err_0 = np.mean(lc.flux_err.value), 
                      P_orb = P_orb,
                      contrast_curve_file = contrastcurve_file,
                      filt = band,
                      exptime = 0.0013888888888889,
                      parallel=True)
    FPPs[i] = target.FPP
    NFPPs[i] = target.NFPP
    print("FPP = ", target.FPP)
    print("NFPP = ", target.NFPP)
# Out:
# Calculating TP scenario probabilitiey for 9006668.
# Calculating EB and EBx2P scenario probabilities for 9006668.
# Calculating PTP scenario probability for 9006668.
# Calculating PEB and PEBx2P scenario probabilities for 9006668.
# Calculating STP scenario probability for 9006668.
# Calculating SEB and SEBx2P scenario probabilities for 9006668.
# Calculating DTP scenario probability for 9006668.
# Calculating DEB and DEBx2P scenario probabilities for 9006668.
# Calculating BTP scenario probability for 9006668.
# Calculating BEB and BEBx2P scenario probabilities for 9006668.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 9006666.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 10000007152.
# FPP =  0.002595086848908079
# NFPP =  0.0001353781860195492
# Calculating TP scenario probabilitiey for 9006668.
# Calculating EB and EBx2P scenario probabilities for 9006668.
# Calculating PTP scenario probability for 9006668.
# Calculating PEB and PEBx2P scenario probabilities for 9006668.
# Calculating STP scenario probability for 9006668.
# Calculating SEB and SEBx2P scenario probabilities for 9006668.
# Calculating DTP scenario probability for 9006668.
# Calculating DEB and DEBx2P scenario probabilities for 9006668.
# Calculating BTP scenario probability for 9006668.
# Calculating BEB and BEBx2P scenario probabilities for 9006668.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 9006666.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 10000007152.
# FPP =  0.001973579931435321
# NFPP =  0.00013380007603046721
# Calculating TP scenario probabilitiey for 9006668.
# Calculating EB and EBx2P scenario probabilities for 9006668.
# Calculating PTP scenario probability for 9006668.
# Calculating PEB and PEBx2P scenario probabilities for 9006668.
# Calculating STP scenario probability for 9006668.
# Calculating SEB and SEBx2P scenario probabilities for 9006668.
# Calculating DTP scenario probability for 9006668.
# Calculating DEB and DEBx2P scenario probabilities for 9006668.
# Calculating BTP scenario probability for 9006668.
# Calculating BEB and BEBx2P scenario probabilities for 9006668.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 9006666.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 10000007152.
# FPP =  0.00233921195010911
# NFPP =  0.00015110579525787234
# Calculating TP scenario probabilitiey for 9006668.
# Calculating EB and EBx2P scenario probabilities for 9006668.
# Calculating PTP scenario probability for 9006668.
# Calculating PEB and PEBx2P scenario probabilities for 9006668.
# Calculating STP scenario probability for 9006668.
# Calculating SEB and SEBx2P scenario probabilities for 9006668.
# Calculating DTP scenario probability for 9006668.
# Calculating DEB and DEBx2P scenario probabilities for 9006668.
# Calculating BTP scenario probability for 9006668.
# Calculating BEB and BEBx2P scenario probabilities for 9006668.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 9006666.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 10000007152.
# FPP =  0.0019462581639054788
# NFPP =  0.0001307746614256445
# Calculating TP scenario probabilitiey for 9006668.
# Calculating EB and EBx2P scenario probabilities for 9006668.
# Calculating PTP scenario probability for 9006668.
# Calculating PEB and PEBx2P scenario probabilities for 9006668.
# Calculating STP scenario probability for 9006668.
# Calculating SEB and SEBx2P scenario probabilities for 9006668.
# Calculating DTP scenario probability for 9006668.
# Calculating DEB and DEBx2P scenario probabilities for 9006668.
# Calculating BTP scenario probability for 9006668.
# Calculating BEB and BEBx2P scenario probabilities for 9006668.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 9006666.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 10000007152.
# FPP =  0.0018533679864038977
# NFPP =  0.00014220285899138133

# %%
df_results = target.probs
print("FPP = ", target.FPP)
print("NFPP = ", target.NFPP)
df_results
# Out:
# FPP =  0.0018533679864038977
# NFPP =  0.00014220285899138133
#              ID scenario       M_s       R_s     P_orb        inc         b  \
# 0       9006668       TP  0.840000  0.766028  1.273114  84.458984  0.606621
# 1       9006668       EB  0.840000  0.766028  1.273114  60.163267  1.371365
# 2       9006668    EBx2P  0.840000  0.766028  2.546228  83.528778  0.604769
# 3       9006668      PTP  0.840000  0.766028  1.273114  84.908635  0.549719
# 4       9006668      PEB  0.840000  0.766028  1.273114  39.315921  1.774379
# 5       9006668   PEBx2P  0.840000  0.766028  2.546228  82.138621  1.769306
# 6       9006668      STP  0.582058  0.586403  1.273114  89.173205  0.099868
# 7       9006668      SEB  0.210803  0.239802  1.273114  87.111974  0.121620
# 8       9006668   SEBx2P  0.315243  0.330798  2.546228  87.041635  0.477049
# 9       9006668      DTP  0.840000  0.766028  1.273114  84.377809  0.574108
# 10      9006668      DEB  0.840000  0.766028  1.273114  50.566732  1.675147
# 11      9006668   DEBx2P  0.840000  0.766028  2.546228  82.404692  1.647448
# 12      9006668      BTP  0.743000  0.693471  1.273114  87.879946  0.207505
# 13      9006668      BEB  0.770000  0.801271  1.273114  88.694050  0.135452
# 14      9006668   BEBx2P  0.918000  0.943963  2.546228  80.720716  1.732399
# 15      9006666      NTP  1.240000  2.107990  1.273114  58.552457  0.957861
# 16      9006666      NEB  1.240000  2.107990  1.273114  55.578717  1.114878
# 17      9006666   NEBx2P  1.240000  2.107990  2.546228  71.039660  1.606162
# 18  10000007152      NTP  1.000000  1.000000  1.273114  89.363674  0.044280
# 19  10000007152      NEB  1.000000  1.000000  1.273114  89.999904  0.000010
# 20  10000007152   NEBx2P  1.000000  1.000000  2.546228  89.571712  0.059398
#
#          ecc           w        R_p      M_EB      R_EB          prob
# 0   0.140046  200.843716   1.720993  0.000000  0.000000  9.242138e-01
# 1   0.635560   83.231162   0.000000  0.756887  0.766028  2.053989e-43
# 2   0.667440  157.297594   0.000000  0.836626  0.766028  1.325938e-29
# 3   0.040596  207.385142   1.679686  0.000000  0.000000  3.577915e-02
# 4   0.710449   63.819065   0.000000  0.782755  0.766028  3.360822e-44
# 5   0.580054  220.487809   0.000000  0.829773  0.766028  8.639780e-28
# 6   0.019084  119.539061   3.612391  0.000000  0.000000  9.046458e-04
# 7   0.889336  172.483486   0.000000  0.033590  0.100000  4.547279e-09
# 8   0.763003  186.481486   0.000000  0.303807  0.321102  6.126084e-07
# 9   0.174235  177.540845   1.744409  0.000000  0.000000  3.815369e-02
# 10  0.663397   65.248828   0.000000  0.760182  0.766028  1.516617e-46
# 11  0.573367  217.242195   0.000000  0.818482  0.766028  4.984851e-29
# 12  0.131700   84.311814  17.137326  0.000000  0.000000  7.094611e-05
# 13  0.056884  356.438639   0.000000  0.123228  0.150959  7.162817e-04
# 14  0.084541  308.514680   0.000000  0.878405  0.910059  1.867438e-05
# 15  0.553147  355.058599  19.704139  0.000000  0.000000  8.590158e-18
# 16  0.486195    4.059476   0.000000  0.238872  0.264880  1.419616e-04
# 17  0.121941  358.098532   0.000000  1.179905  1.318565  3.504163e-08
# 18  0.248818  139.057182  19.981514  0.000000  0.000000  5.353939e-49
# 19  0.040257   41.101168   0.000000  0.721056  0.752363  2.052770e-07
# 20  0.322195   19.227135   0.000000  0.952416  1.000000  9.212746e-10

# %%
target.plot_fits(time=time, flux_0=flux, flux_err_0=np.mean(flux_err))

# %%
for i in range (len(FPPs)):
    print(FPPs[i],",")

print("NFPPs:")
for i in range (len(FPPs)):
    print(NFPPs[i],",")
# Out:
# 0.002595086848908079 ,
# 0.001973579931435321 ,
# 0.00233921195010911 ,
# 0.0019462581639054788 ,
# 0.0018533679864038977 ,
# NFPPs:
# 0.0001353781860195492 ,
# 0.00013380007603046721 ,
# 0.00015110579525787234 ,
# 0.0001307746614256445 ,
# 0.00014220285899138133 ,

# %% [markdown]
# ### Reinitialization for BrGamma

# %%
ID = 9006668
sectors = np.array([2,29])

period = 1.2731140178
tdepth = 0.000391117

lc_file = "TOI_238_S02_29.csv"
contrastcurve_file = "TOI_238_BrGamma.csv"

band = 'K'

# %%
cc = pd.read_csv(contrastcurve_file, header=None)
sep, dmag = cc[0].values, cc[1].values

plt.plot(sep, dmag, 'k-');
plt.ylim(11,0);
plt.ylabel("$\\Delta K_s$", fontsize=20);
plt.xlabel("separation ('')", fontsize=20);

# %%
# %%time

lc = pd.read_csv(lc_file, header=None)

# read in the light curve
time, flux, flux_err = lc[0].values, lc[1].values, lc[2].values
P_orb = period

lc_binsize = (time.max()-time.min())/200
lc = TessLightCurve(time=time, flux=flux, flux_err=flux_err).bin(time_bin_size=lc_binsize)

plt.scatter(time, flux, s = 5, c = 'c')
plt.scatter(lc.time.value, lc.flux.value, s = 25,  c = 'b')
fig=plt.gcf()
fig.set_size_inches(8,5)
# Out:
# CPU times: total: 2.53 s
# Wall time: 2.53 s

# %%
FPPs = np.zeros(5)
NFPPs = np.zeros(5)
for i in range(5):
    target.calc_probs(time = lc.time.value, 
                      flux_0 = lc.flux.value, 
                      flux_err_0 = np.mean(lc.flux_err.value), 
                      P_orb = P_orb,
                      contrast_curve_file = contrastcurve_file,
                      filt = band,
                      exptime = 0.0013888888888889,
                      parallel=True)
    FPPs[i] = target.FPP
    NFPPs[i] = target.NFPP
    print("FPP = ", target.FPP)
    print("NFPP = ", target.NFPP)
# Out:
# Calculating TP scenario probabilitiey for 9006668.
# Calculating EB and EBx2P scenario probabilities for 9006668.
# Calculating PTP scenario probability for 9006668.
# Calculating PEB and PEBx2P scenario probabilities for 9006668.
# Calculating STP scenario probability for 9006668.
# Calculating SEB and SEBx2P scenario probabilities for 9006668.
# Calculating DTP scenario probability for 9006668.
# Calculating DEB and DEBx2P scenario probabilities for 9006668.
# Calculating BTP scenario probability for 9006668.
# Calculating BEB and BEBx2P scenario probabilities for 9006668.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 9006666.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 10000007152.
# FPP =  0.002813666063671727
# NFPP =  0.0001636458020755476
# Calculating TP scenario probabilitiey for 9006668.
# Calculating EB and EBx2P scenario probabilities for 9006668.
# Calculating PTP scenario probability for 9006668.
# Calculating PEB and PEBx2P scenario probabilities for 9006668.
# Calculating STP scenario probability for 9006668.
# Calculating SEB and SEBx2P scenario probabilities for 9006668.
# Calculating DTP scenario probability for 9006668.
# Calculating DEB and DEBx2P scenario probabilities for 9006668.
# Calculating BTP scenario probability for 9006668.
# Calculating BEB and BEBx2P scenario probabilities for 9006668.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 9006666.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 10000007152.
# FPP =  0.002757124215164497
# NFPP =  0.00013158003716291352
# Calculating TP scenario probabilitiey for 9006668.
# Calculating EB and EBx2P scenario probabilities for 9006668.
# Calculating PTP scenario probability for 9006668.
# Calculating PEB and PEBx2P scenario probabilities for 9006668.
# Calculating STP scenario probability for 9006668.
# Calculating SEB and SEBx2P scenario probabilities for 9006668.
# Calculating DTP scenario probability for 9006668.
# Calculating DEB and DEBx2P scenario probabilities for 9006668.
# Calculating BTP scenario probability for 9006668.
# Calculating BEB and BEBx2P scenario probabilities for 9006668.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 9006666.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 10000007152.
# FPP =  0.0027657922227373177
# NFPP =  0.00013160171715872812
# Calculating TP scenario probabilitiey for 9006668.
# Calculating EB and EBx2P scenario probabilities for 9006668.
# Calculating PTP scenario probability for 9006668.
# Calculating PEB and PEBx2P scenario probabilities for 9006668.
# Calculating STP scenario probability for 9006668.
# Calculating SEB and SEBx2P scenario probabilities for 9006668.
# Calculating DTP scenario probability for 9006668.
# Calculating DEB and DEBx2P scenario probabilities for 9006668.
# Calculating BTP scenario probability for 9006668.
# Calculating BEB and BEBx2P scenario probabilities for 9006668.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 9006666.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 10000007152.
# FPP =  0.0029977998761026026
# NFPP =  0.00011393999914417734
# Calculating TP scenario probabilitiey for 9006668.
# Calculating EB and EBx2P scenario probabilities for 9006668.
# Calculating PTP scenario probability for 9006668.
# Calculating PEB and PEBx2P scenario probabilities for 9006668.
# Calculating STP scenario probability for 9006668.
# Calculating SEB and SEBx2P scenario probabilities for 9006668.
# Calculating DTP scenario probability for 9006668.
# Calculating DEB and DEBx2P scenario probabilities for 9006668.
# Calculating BTP scenario probability for 9006668.
# Calculating BEB and BEBx2P scenario probabilities for 9006668.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 9006666.
# Calculating NTP, NEB, and NEB2xP scenario probabilities for 10000007152.
# FPP =  0.0030678690420221644
# NFPP =  0.00012380696090657508

# %%
df_results = target.probs
print("FPP = ", target.FPP)
print("NFPP = ", target.NFPP)
df_results
# Out:
# FPP =  0.0030678690420221644
# NFPP =  0.00012380696090657508
#              ID scenario       M_s       R_s     P_orb        inc         b  \
# 0       9006668       TP  0.840000  0.766028  1.273114  84.554324  0.592082
# 1       9006668       EB  0.840000  0.766028  1.273114  45.277847  1.671968
# 2       9006668    EBx2P  0.840000  0.766028  2.546228  84.619288  0.506263
# 3       9006668      PTP  0.840000  0.766028  1.273114  84.549648  0.576136
# 4       9006668      PEB  0.840000  0.766028  1.273114  32.897365  1.952472
# 5       9006668   PEBx2P  0.840000  0.766028  2.546228  83.838418  0.473464
# 6       9006668      STP  0.575319  0.581607  1.273114  88.912799  0.137371
# 7       9006668      SEB  0.224867  0.252435  1.273114  87.013990  0.242008
# 8       9006668   SEBx2P  0.175594  0.207304  2.546228  87.529816  0.640998
# 9       9006668      DTP  0.840000  0.766028  1.273114  85.861409  0.496475
# 10      9006668      DEB  0.840000  0.766028  1.273114  53.629600  1.495536
# 11      9006668   DEBx2P  0.840000  0.766028  2.546228  84.027022  0.622347
# 12      9006668      BTP  0.925000  0.862193  1.273114  88.658646  0.033000
# 13      9006668      BEB  1.053000  1.102169  1.273114  83.969267  0.398635
# 14      9006668   BEBx2P  0.749000  0.685922  2.546228  83.931633  1.491870
# 15      9006666      NTP  1.240000  2.107990  1.273114  56.804290  0.934838
# 16      9006666      NEB  1.240000  2.107990  1.273114  56.310128  1.085035
# 17      9006666   NEBx2P  1.240000  2.107990  2.546228  68.108434  1.615303
# 18  10000007152      NTP  1.000000  1.000000  1.273114  89.247624  0.064228
# 19  10000007152      NEB  1.000000  1.000000  1.273114  89.936190  0.006595
# 20  10000007152   NEBx2P  1.000000  1.000000  2.546228  89.457139  0.093444
#
#          ecc           w        R_p      M_EB      R_EB          prob
# 0   0.120457  198.497907   1.702044  0.000000  0.000000  8.275625e-01
# 1   0.694011   67.593773   0.000000  0.745677  0.766028  8.896425e-44
# 2   0.764728  185.275698   0.000000  0.803552  0.766028  1.427431e-14
# 3   0.119074  185.020470   1.765904  0.000000  0.000000  4.114996e-02
# 4   0.713776   54.312288   0.000000  0.722879  0.754172  3.821104e-46
# 5   0.742815  161.818462   0.000000  0.817284  0.766028  8.250058e-29
# 6   0.026737  245.412545   3.652281  0.000000  0.000000  2.063424e-03
# 7   0.800517  182.763955   0.000000  0.031215  0.100000  1.761440e-13
# 8   0.775373  201.750083   0.000000  0.170581  0.202467  1.358442e-08
# 9   0.144464  292.585184   1.648837  0.000000  0.000000  1.282197e-01
# 10  0.670955   75.769354   0.000000  0.774316  0.766028  1.630713e-43
# 11  0.654619  165.602700   0.000000  0.836368  0.766028  1.595723e-30
# 12  0.749878  101.665750   6.813825  0.000000  0.000000  8.984006e-05
# 13  0.322181   23.166413   0.000000  0.150242  0.181839  7.803053e-04
# 14  0.425609  215.263151   0.000000  0.718152  0.685922  1.047902e-05
# 15  0.525850    7.373937  19.894999  0.000000  0.000000  6.482174e-18
# 16  0.473511    7.255690   0.000000  0.239683  0.265597  1.235708e-04
# 17  0.247527   20.080895   0.000000  1.193908  1.334675  3.046429e-08
# 18  0.072166  175.736153  19.983511  0.000000  0.000000  5.355548e-49
# 19  0.030416    0.069944   0.000000  0.724133  0.755410  2.047414e-07
# 20  0.307968  341.039255   0.000000  0.951357  1.000000  9.598741e-10

# %%
for i in range (len(FPPs)):
    print(FPPs[i],",")

print("NFPPs:")
for i in range (len(FPPs)):
    print(NFPPs[i],",")
# Out:
# 0.002813666063671727 ,
# 0.002757124215164497 ,
# 0.0027657922227373177 ,
# 0.0029977998761026026 ,
# 0.0030678690420221644 ,
# NFPPs:
# 0.0001636458020755476 ,
# 0.00013158003716291352 ,
# 0.00013160171715872812 ,
# 0.00011393999914417734 ,
# 0.00012380696090657508 ,

# %%
# BrGamma

FPP = np.array([0.002813666063671727 ,
0.002757124215164497 ,
0.0027657922227373177 ,
0.0029977998761026026 ,
0.0030678690420221644])
NFPP= np.array([0.0001636458020755476 ,
0.00013158003716291352 ,
0.00013160171715872812 ,
0.00011393999914417734 ,
0.00012380696090657508 ])

print("Mean FPP = ",np.round(np.mean(FPP),5))
print("Standard Deviation FPP = ",np.round(np.std(FPP),8))
# Out:
# Mean FPP =  0.00248
# Standard Deviation FPP =  0.00017257

# %%
# visible 562nm

FPP = np.array([0.002595086848908079 ,
0.001973579931435321 ,
0.00233921195010911 ,
0.0019462581639054788 ,
0.0018533679864038977])
NFPP= np.array([0.0001353781860195492 ,
0.00013380007603046721 ,
0.00015110579525787234 ,
0.0001307746614256445 ,
0.00014220285899138133])

print("Mean FPP = ",np.round(np.mean(FPP),5))
print("Standard Deviation FPP = ",np.round(np.std(FPP),8))
# Out:
# Mean FPP =  0.0025
# Standard Deviation FPP =  0.00017103

# %%
# tess 832nm

FPP = np.array([0.002203133010089675 ,
0.002337185656669738 ,
0.002227303899572708 ,
0.00210923941585317 ,
0.002256128583671635])
NFPP= np.array([0.00013688189085215693 ,
0.00015243610888995233 ,
0.0001285253999908043 ,
0.00014764213782096603 ,
0.0001433549974551288])

print("Mean FPP = ",np.round(np.mean(FPP),5))
print("Standard Deviation FPP = ",np.round(np.std(FPP),8))
# Out:
# Mean FPP =  0.00223
# Standard Deviation FPP =  7.406e-05
